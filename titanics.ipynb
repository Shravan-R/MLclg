# %%
#Bringing the csv file 

import pandas as pd
df=pd.read_csv('titanic.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#now add a new column
# Create the new column values
row_numbers = range(1, len(df) + 1)

# %%
# This will insert at position 2 (indexing starts from 0)
df.insert(loc=2, column='PassengerCode', value=range(1001, 1001 + len(df)))

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df
# Out:
#      PassengerId  Survived  PassengerCode  Pclass  \
# 0              1         0           1001       3
# 1              2         1           1002       1
# 2              3         1           1003       3
# 3              4         1           1004       1
# 4              5         0           1005       3
# ..           ...       ...            ...     ...
# 886          887         0           1887       2
# 887          888         1           1888       1
# 888          889         0           1889       3
# 889          890         1           1890       1
# 890          891         0           1891       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# ...

# %%
# seeing which column is having nan value
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# PassengerCode    0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         0
# RowNumber        0
# dtype: int64

# %%
#filling the NaN place with some random value 
#using fillna 
df = df.fillna('Unknown')
print(df)
# Out:
#      PassengerId  Survived  PassengerCode  Pclass  \
# 0              1         0           1001       3
# 1              2         1           1002       1
# 2              3         1           1003       3
# 3              4         1           1004       1
# 4              5         0           1005       3
# ..           ...       ...            ...     ...
# 886          887         0           1887       2
# 887          888         1           1888       1
# 888          889         0           1889       3
# 889          890         1           1890       1
# 890          891         0           1891       3
#
#                                                   Name     Sex      Age  \
# 0                              Braund, Mr. Owen Harris    male     22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female     38.0
# 2                                Heikkinen, Miss Laina  female     26.0
# ...
